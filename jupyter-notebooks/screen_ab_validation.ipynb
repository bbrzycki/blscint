# %% [markdown]
# # Screen Propagation: c95 vs rd18 A/B Validation
#
# This notebook checks whether the Coles-style wrapper and Ravi/Deshpande-style wrapper can produce the same result when they are given the same physical screen, same random seed, same propagation kernel, and same phase-sign convention.
#
# This is intentionally different from asking whether the default paper parameterizations are identical.  The default `rd18` path can still be driven by `C_n2` and its paper sign convention; this matched mode proves that the implementation layers now share a common backend.

# %% [markdown]
# ![c95 rd18 A/B validation](figures/validation_c95_rd18_ab.png)

# %% [markdown]
# Current matched-mode results:
#
# - Phase-screen correlation: `1.0`.
# - Dynamic-spectrum correlation: `1.0`.
# - Max absolute intensity residual: `0.0`.
#
# That means the previous mismatch was not an unavoidable paper conflict.  It came from mismatched parameterization, propagation kernels, first-screen propagation order, and phase-sign convention.

# %% [markdown]
# ## Regenerate

# %%
# %run generate_screen_ab_figures.py
